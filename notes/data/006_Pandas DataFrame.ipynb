# %%
import pandas as pd
import numpy as np
import itertools

# %% [markdown]
# # DataFrame
# DataFrame is a __2-dimensional__ labeled data structure with columns
# Accepts:
# 1. Dict of 1D ndarrays, lists, dicts, or Series
# 2. 2-D numpy.ndarray
# 3. Structured or record ndarray (Array with named fields)
# 4. A pd.Series
# 5. Another DataFrame

# %%
df = pd.DataFrame(np.random.rand(6, 4)*100,
                  index=['a', 'b', 'c', 'd', 'e', 'f'],
                  columns=['one', 'two', 'three', 'four']) # Create a 6x4 Dataframe

# %%
df
# Out:
#          one        two      three       four
# a  76.453545  96.363305  34.309186  22.437078
# b   7.051927   6.406754  61.736579  67.622311
# c  35.462478  97.267604  10.570521  18.526606
# d   8.456016  15.859291  42.272089  72.040873
# e  30.148330   9.196565  66.528700  28.383170
# f  13.589995  12.772728  80.112225  55.187197

# %% [markdown]
# ## Selecting elements

# %%
df.index # Get rows
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
df.columns # Get columns
# Out:
# Index(['one', 'two', 'three', 'four'], dtype='object')

# %%
df.loc['a'] # Get rows
# Out:
# one      76.453545
# two      96.363305
# three    34.309186
# four     22.437078
# Name: a, dtype: float64

# %%
df.iloc[0] # Integer index for rows
# Out:
# one      76.453545
# two      96.363305
# three    34.309186
# four     22.437078
# Name: a, dtype: float64

# %%
type(df.iloc[0]) # All rows are pandas.Series
# Out:
# pandas.core.series.Series

# %%
df.head(n=3) # Get first n rows
# Out:
#          one        two      three       four
# a  76.453545  96.363305  34.309186  22.437078
# b   7.051927   6.406754  61.736579  67.622311
# c  35.462478  97.267604  10.570521  18.526606

# %%
df['one'] # Get column
# Out:
# a    76.453545
# b     7.051927
# c    35.462478
# d     8.456016
# e    30.148330
# f    13.589995
# Name: one, dtype: float64

# %%
df.one # Scary notation, may shadow in-built functions, Try Avoiding it
# Out:
# a    76.453545
# b     7.051927
# c    35.462478
# d     8.456016
# e    30.148330
# f    13.589995
# Name: one, dtype: float64

# %%
type(df['two']) # Columns are also pandas.Series
# Out:
# pandas.core.series.Series

# %%
df.loc[['a', 'b']] # Get two(Multiple) rows
# Out:
#          one        two      three       four
# a  76.453545  96.363305  34.309186  22.437078
# b   7.051927   6.406754  61.736579  67.622311

# %%
df[['two', 'one']] # Get two(Multiple) columns
# Out:
#          two        one
# a  96.363305  76.453545
# b   6.406754   7.051927
# c  97.267604  35.462478
# d  15.859291   8.456016
# e   9.196565  30.148330
# f  12.772728  13.589995

# %%
df.loc[['a', 'b'], ['one']] # Get multiple rows and columns
# Out:
#          one
# a  76.453545
# b   7.051927

# %%
df.loc[['b', 'c', 'a', 'e'], ['two', 'one']] # Change the selection order
# Out:
#          two        one
# b   6.406754   7.051927
# c  97.267604  35.462478
# a  96.363305  76.453545
# e   9.196565  30.148330

# %%
df.shape # Get shape
# Out:
# (6, 4)

# %% [markdown]
# ## Conditional selection

# %%
df > df.median() # All values <,> are reflected as true or false
# Out:
#      one    two  three   four
# a   True   True  False  False
# b  False  False   True   True
# c   True   True  False  False
# d  False   True  False   True
# e   True  False   True  False
# f  False  False   True   True

# %%
df[df > df.median()] # Get NaN for every false value above
# Out:
#          one        two      three       four
# a  76.453545  96.363305        NaN        NaN
# b        NaN        NaN  61.736579  67.622311
# c  35.462478  97.267604        NaN        NaN
# d        NaN  15.859291        NaN  72.040873
# e  30.148330        NaN  66.528700        NaN
# f        NaN        NaN  80.112225  55.187197

# %%
df[df['one'] > 50] # Using conditional selection for columns returns reduced dataframe
# Out:
#          one        two      three       four
# a  76.453545  96.363305  34.309186  22.437078

# %%
df[df['one'] > 50]['two'] # Now get the row 'two' from the modified dataframe
# Out:
# a    96.363305
# Name: two, dtype: float64

# %%
df[df['one'] > 50][['two', 'three']] # Get multiple columns
# Out:
#          two      three
# a  96.363305  34.309186

# %%
df[(df['one'] > 50) & (df['two'] < 50)] # Anding out multiple conditions using the & operator(and doesn't work)
# Out:
# Empty DataFrame
# Columns: [one, two, three, four]
# Index: []

# %%
df[(df['three'] > 50) | (df['four'] > 90)] # Or operation using | operator
# Out:
#          one        two      three       four
# b   7.051927   6.406754  61.736579  67.622311
# e  30.148330   9.196565  66.528700  28.383170
# f  13.589995  12.772728  80.112225  55.187197

# %% [markdown]
# ## Operations on Dataframes

# %%
df['three'] = df['one'] + df['two'] # Adding columns

# %%
df
# Out:
#          one        two       three       four
# a  76.453545  96.363305  172.816850  22.437078
# b   7.051927   6.406754   13.458681  67.622311
# c  35.462478  97.267604  132.730082  18.526606
# d   8.456016  15.859291   24.315307  72.040873
# e  30.148330   9.196565   39.344895  28.383170
# f  13.589995  12.772728   26.362723  55.187197

# %%
df
# Out:
#          one        two       three       four
# a  76.453545  96.363305  172.816850  22.437078
# b   7.051927   6.406754   13.458681  67.622311
# c  35.462478  97.267604  132.730082  18.526606
# d   8.456016  15.859291   24.315307  72.040873
# e  30.148330   9.196565   39.344895  28.383170
# f  13.589995  12.772728   26.362723  55.187197

# %%
df.drop('a', axis=0) # Remove rows
# Out:
#          one        two       three       four
# b   7.051927   6.406754   13.458681  67.622311
# c  35.462478  97.267604  132.730082  18.526606
# d   8.456016  15.859291   24.315307  72.040873
# e  30.148330   9.196565   39.344895  28.383170
# f  13.589995  12.772728   26.362723  55.187197

# %%
df.drop('three', axis=1) # Remove Column
# Out:
#          one        two       four
# a  76.453545  96.363305  22.437078
# b   7.051927   6.406754  67.622311
# c  35.462478  97.267604  18.526606
# d   8.456016  15.859291  72.040873
# e  30.148330   9.196565  28.383170
# f  13.589995  12.772728  55.187197

# %%
df # Does not loose any row/column as defaults for inplace is false
# Out:
#          one        two       three       four
# a  76.453545  96.363305  172.816850  22.437078
# b   7.051927   6.406754   13.458681  67.622311
# c  35.462478  97.267604  132.730082  18.526606
# d   8.456016  15.859291   24.315307  72.040873
# e  30.148330   9.196565   39.344895  28.383170
# f  13.589995  12.772728   26.362723  55.187197

# %%
df.loc['f'] = df.loc['e'] + df.loc['a'] # Add rows

# %%
df['temp'] = df['one'] + df['two'] + df['three']

# %%
df
# Out:
#           one         two       three       four        temp
# a   76.453545   96.363305  172.816850  22.437078  345.633700
# b    7.051927    6.406754   13.458681  67.622311   26.917362
# c   35.462478   97.267604  132.730082  18.526606  265.460164
# d    8.456016   15.859291   24.315307  72.040873   48.630614
# e   30.148330    9.196565   39.344895  28.383170   78.689790
# f  106.601874  105.559871  212.161745  50.820248  424.323490

# %%
df.drop('temp', axis=1, inplace=True) # Alters columns of dataframe df

# %%
df.drop('f', axis=0, inplace=True) # Alters rows of dataframe df

# %%
df # Resultant dataframe
# Out:
#          one        two       three       four
# a  76.453545  96.363305  172.816850  22.437078
# b   7.051927   6.406754   13.458681  67.622311
# c  35.462478  97.267604  132.730082  18.526606
# d   8.456016  15.859291   24.315307  72.040873
# e  30.148330   9.196565   39.344895  28.383170

# %%
df.reset_index() # Reset index to integer values(inplace=False as default)
# Out:
#   index        one        two       three       four
# 0     a  76.453545  96.363305  172.816850  22.437078
# 1     b   7.051927   6.406754   13.458681  67.622311
# 2     c  35.462478  97.267604  132.730082  18.526606
# 3     d   8.456016  15.859291   24.315307  72.040873
# 4     e  30.148330   9.196565   39.344895  28.383170

# %%
df
# Out:
#          one        two       three       four
# a  76.453545  96.363305  172.816850  22.437078
# b   7.051927   6.406754   13.458681  67.622311
# c  35.462478  97.267604  132.730082  18.526606
# d   8.456016  15.859291   24.315307  72.040873
# e  30.148330   9.196565   39.344895  28.383170

# %%
newIndex = 'H He Li Be B'.split()

# %%
newIndex
# Out:
# ['H', 'He', 'Li', 'Be', 'B']

# %%
df['elements'] = newIndex

# %%
df
# Out:
#          one        two       three       four elements
# a  76.453545  96.363305  172.816850  22.437078        H
# b   7.051927   6.406754   13.458681  67.622311       He
# c  35.462478  97.267604  132.730082  18.526606       Li
# d   8.456016  15.859291   24.315307  72.040873       Be
# e  30.148330   9.196565   39.344895  28.383170        B

# %%
df.set_index('elements') # Set column as index
# Out:
#                 one        two       three       four
# elements
# H         76.453545  96.363305  172.816850  22.437078
# He         7.051927   6.406754   13.458681  67.622311
# Li        35.462478  97.267604  132.730082  18.526606
# Be         8.456016  15.859291   24.315307  72.040873
# B         30.148330   9.196565   39.344895  28.383170

# %%
df # set_index also doesn't default to inplace=True
# Out:
#          one        two       three       four elements
# a  76.453545  96.363305  172.816850  22.437078        H
# b   7.051927   6.406754   13.458681  67.622311       He
# c  35.462478  97.267604  132.730082  18.526606       Li
# d   8.456016  15.859291   24.315307  72.040873       Be
# e  30.148330   9.196565   39.344895  28.383170        B

# %% [markdown]
# ## Finding Uniques

# %%
df = pd.DataFrame({'a': [np.random.randint(0, 10) for x in range(0, 20)],
                  'b': [np.random.randint(10, 20) for x in range(0, 20)],
                  'c': [np.random.randint(20, 30) for x in range(0, 20)]})

# %%
df
# Out:
#     a   b   c
# 0   5  13  29
# 1   5  16  27
# 2   2  16  26
# 3   3  12  24
# 4   4  12  26
# 5   3  13  25
# 6   7  13  26
# 7   9  15  22
# 8   6  16  20
# 9   8  18  22
# 10  6  11  29
# 11  9  16  29
# 12  0  14  26
# 13  6  18  25
# 14  4  11  23
# 15  5  10  20
# 16  4  18  26
# 17  0  16  25
# 18  6  10  23
# 19  9  18  26

# %%
df['a'].unique() # Get all unique values
# Out:
# array([5, 2, 3, 4, 7, 9, 6, 8, 0])

# %%
df['b'].nunique() # Get number of unique values
# Out:
# 8

# %%
df['c'].value_counts() # Get count of each unique value
# Out:
# 26    6
# 29    3
# 25    3
# 23    2
# 22    2
# 20    2
# 27    1
# 24    1
# Name: c, dtype: int64

# %% [markdown]
# ## Sorting

# %%
df.sort_values(by='a') # Sort values in column 'a'
# Out:
#     a   b   c
# 17  0  16  25
# 12  0  14  26
# 2   2  16  26
# 3   3  12  24
# 5   3  13  25
# 4   4  12  26
# 16  4  18  26
# 14  4  11  23
# 0   5  13  29
# 1   5  16  27
# 15  5  10  20
# 8   6  16  20
# 18  6  10  23
# 10  6  11  29
# 13  6  18  25
# 6   7  13  26
# 9   8  18  22
# 7   9  15  22
# 11  9  16  29
# 19  9  18  26

# %% [markdown]
# # Multiple Indexes

# %%
outside = ['G1', 'G2']

# %%
inside = [1, 2, 3]

# %%
hier_index = list(itertools.product(outside, inside))

# %%
hier_index
# Out:
# [('G1', 1), ('G1', 2), ('G1', 3), ('G2', 1), ('G2', 2), ('G2', 3)]

# %%
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex(levels=[['G1', 'G2'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]])

# %%
df = pd.DataFrame(np.random.randn(6,2), index=hier_index, columns=['C1', 'C2'])

# %%
df
# Out:
#             C1        C2
# G1 1 -0.398820  0.833642
#    2 -0.919460  1.195630
#    3  1.034852 -0.549340
# G2 1 -0.196821  0.872685
#    2 -0.892006  0.319175
#    3 -0.701212  1.788616

# %%
df.index.names = ['Groups', 'Num'] # Set Names for indexes

# %%
df
# Out:
#                   C1        C2
# Groups Num
# G1     1   -0.398820  0.833642
#        2   -0.919460  1.195630
#        3    1.034852 -0.549340
# G2     1   -0.196821  0.872685
#        2   -0.892006  0.319175
#        3   -0.701212  1.788616

# %%
df.loc['G1'] # Getting a group
# Out:
#            C1        C2
# Num
# 1   -0.398820  0.833642
# 2   -0.919460  1.195630
# 3    1.034852 -0.549340

# %%
df.loc['G2'].loc[2] # Going deeper
# Out:
# C1   -0.892006
# C2    0.319175
# Name: 2, dtype: float64

# %%
df.loc['G2'].loc[2]['C1'] # Get element from index in the hierarchy
# Out:
# -0.89200577621692

# %%
df.xs(1, level='Num') # Cross-section to inner level directly(Here index 1 from Num)
# Out:
#               C1        C2
# Groups
# G1     -0.398820  0.833642
# G2     -0.196821  0.872685

# %% [markdown]
# ## Working with missing Indexes

# %%
df = pd.DataFrame({'a':[1, 2, 3], 'b':[1, 2, np.nan], 'c': [1,np.nan, np.nan]})

# %%
df
# Out:
#    a    b    c
# 0  1  1.0  1.0
# 1  2  2.0  NaN
# 2  3  NaN  NaN

# %%
df.dropna() # Drop all indexes containing Nan
# Out:
#    a    b    c
# 0  1  1.0  1.0

# %%
df.dropna(axis=1) # Or drop all columns containing NaN
# Out:
#    a
# 0  1
# 1  2
# 2  3

# %%
df.dropna(thresh=2) # Allow <2 NaN values
# Out:
#    a    b    c
# 0  1  1.0  1.0
# 1  2  2.0  NaN

# %%
df.fillna(0) # Fill all NaNs with 0
# Out:
#    a    b    c
# 0  1  1.0  1.0
# 1  2  2.0  0.0
# 2  3  0.0  0.0

# %%
df.fillna(value=df['a'].mean())
# Out:
#    a    b    c
# 0  1  1.0  1.0
# 1  2  2.0  2.0
# 2  3  2.0  2.0

# %% [markdown]
# ## Groupby

# %%
company = (['GOOG', 'AMZN', 'MSFT', 'FB'] * 4)
company = sorted(company, key=str.upper)
dept = ['ADS', 'HW', 'SW', 'VR'] * 4
randvals = [np.random.randint(100, 500) for x in range(16)]

# %%
baddf = pd.DataFrame({'Company': company, 'dept':dept, 'sales': randvals})

# %%
baddf
# Out:
#    Company dept  sales
# 0     AMZN  ADS    336
# 1     AMZN   HW    103
# 2     AMZN   SW    284
# 3     AMZN   VR    431
# 4       FB  ADS    492
# 5       FB   HW    387
# 6       FB   SW    299
# 7       FB   VR    297
# 8     GOOG  ADS    284
# 9     GOOG   HW    142
# 10    GOOG   SW    395
# 11    GOOG   VR    424
# 12    MSFT  ADS    380
# 13    MSFT   HW    120
# 14    MSFT   SW    246
# 15    MSFT   VR    449

# %%
company_grp = baddf.groupby('Company') # Step 1: Create Group

# %%
company_grp

# %%
company_grp.mean() # Step 2: Apply aggregate functions
# Out:
#           sales
# Company
# AMZN     288.50
# FB       368.75
# GOOG     311.25
# MSFT     298.75

# %%
company_grp.sum() # More methods on groupby(Sum)
# Out:
#          sales
# Company
# AMZN      1154
# FB        1475
# GOOG      1245
# MSFT      1195

# %%
company_grp.std() # Even more method(Standard deviation)
# Out:
#               sales
# Company
# AMZN     137.832023
# FB        92.261856
# GOOG     127.951488
# MSFT     145.957471

# %%
company_grp.sum().loc['GOOG'] # Accessing values by index after applying aggregate methods
# Out:
# sales    1245
# Name: GOOG, dtype: int64

# %%
baddf.groupby('Company').sum().loc['FB'] # Putting all the steps together
# Out:
# sales    1475
# Name: FB, dtype: int64

# %%
baddf.groupby('Company').describe() # Tabulate various results
# Out:
#         sales
#         count    mean         std    min     25%    50%     75%    max
# Company
# AMZN      4.0  288.50  137.832023  103.0  238.75  310.0  359.75  431.0
# FB        4.0  368.75   92.261856  297.0  298.50  343.0  413.25  492.0
# GOOG      4.0  311.25  127.951488  142.0  248.50  339.5  402.25  424.0
# MSFT      4.0  298.75  145.957471  120.0  214.50  313.0  397.25  449.0

# %% [markdown]
# ## Concatenation
# Cocatenate pandas object along a particular axis

# %%
x4_arr = lambda x,y: np.array([x for x in range(x,y)]).reshape(4,4)
columns = ['A', 'B', 'C', 'D']
df1 = pd.DataFrame(x4_arr(0, 16), index=[0, 1, 2, 3], columns=columns)
df2 = pd.DataFrame(x4_arr(16, 32), index=[4, 5, 6, 7], columns=columns)
df3 = pd.DataFrame(x4_arr(32, 48), index=[8, 9, 10, 11], columns=columns)

# %%
df1
# Out:
#     A   B   C   D
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df2
# Out:
#     A   B   C   D
# 4  16  17  18  19
# 5  20  21  22  23
# 6  24  25  26  27
# 7  28  29  30  31

# %%
df3
# Out:
#      A   B   C   D
# 8   32  33  34  35
# 9   36  37  38  39
# 10  40  41  42  43
# 11  44  45  46  47

# %%
pd.concat([df1, df2, df3]) # Concatenation along index
# Out:
#      A   B   C   D
# 0    0   1   2   3
# 1    4   5   6   7
# 2    8   9  10  11
# 3   12  13  14  15
# 4   16  17  18  19
# 5   20  21  22  23
# 6   24  25  26  27
# 7   28  29  30  31
# 8   32  33  34  35
# 9   36  37  38  39
# 10  40  41  42  43
# 11  44  45  46  47

# %%
pd.concat([df1, df2, df3], axis=1) # Concatenation along columns
# Out:
#        A     B     C     D     A     B     C     D     A     B     C     D
# 0    0.0   1.0   2.0   3.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1    4.0   5.0   6.0   7.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2    8.0   9.0  10.0  11.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   12.0  13.0  14.0  15.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    NaN   NaN   NaN   NaN  16.0  17.0  18.0  19.0   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN   NaN  20.0  21.0  22.0  23.0   NaN   NaN   NaN   NaN
# 6    NaN   NaN   NaN   NaN  24.0  25.0  26.0  27.0   NaN   NaN   NaN   NaN
# 7    NaN   NaN   NaN   NaN  28.0  29.0  30.0  31.0   NaN   NaN   NaN   NaN
# 8    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  32.0  33.0  34.0  35.0
# 9    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  36.0  37.0  38.0  39.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  40.0  41.0  42.0  43.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  44.0  45.0  46.0  47.0

# %% [markdown]
# ## Merging
# Concatenate(?) over a key

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(left, right, how="inner", on="key") # Exclude all unmatching keys
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right, on=['key1'])
# Out:
#   key1 key2_x   A   B key2_y   C   D
# 0   K0     K0  A0  B0     K0  C0  D0
# 1   K0     K1  A1  B1     K0  C0  D0
# 2   K1     K0  A2  B2     K0  C1  D1
# 3   K1     K0  A2  B2     K0  C2  D2
# 4   K2     K1  A3  B3     K0  C3  D3

# %%
pd.merge(left, right, on=['key1', 'key2']) # Use list as key
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
pd.merge(left, right, how='outer', on=['key1', 'key2']) # All key values from both dataframes, NaN for absent values
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %%
pd.merge(left, right, how='left', on=['key1', 'key2']) # All key values from left dataframe
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %%
pd.merge(left, right, how='right', on=['key1', 'key2']) # All key values from right dataframe
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %% [markdown]
# ## Joining
# Join dataframe columns either along index or key columns

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right) # All rows of left with corresponding values of right
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left.join(right, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# ## Pivots
# Reshape dataframe using pivots

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A', 'B'],columns=['C'])
# Out:
# C          x    y
# A   B
# bar one  4.0  1.0
#     two  NaN  5.0
# foo one  1.0  3.0
#     two  2.0  NaN
